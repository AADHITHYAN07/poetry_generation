# %%
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !locale
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-22-3156e0244c83> in <cell line: 1>()
# ----> 1 get_ipython().system('locale')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
# !pip install datasets nltk rouge

# %%
from datasets import load_dataset
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# Load the dataset from Hugging Face
dataset = load_dataset("merve/poetry")
dataset_train = dataset["train"].select(range(500))

# Specify the genre you're interested in
specific_genre = "nature" # Replace with your specific genre

# Filter the dataset to get poems of the specified genre
filtered_poems = dataset_train.filter(lambda example: example['type'] == specific_genre)

# Assuming you want to compare with the first poem of this genre
existing_genre_poem = filtered_poems['content'][0] if filtered_poems['content'] else "No poem found in this genre."

# Your generated poem
generated_poem = "The sun was shining bright, The bird's feathers were blue, The bird's song was so sweet, The birds were in their nests, The birds and the sun were happy,Nature's beauty was in the air,The world was a beautiful place,The world was a place to be seen,The trees and the sky were all,The trees were green and the sky was blue,The world was a place we all could be proud of,Life is a beautiful thing."

# Function to calculate BLEU score
def calculate_bleu(reference, candidate):
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()
    score = sentence_bleu([reference_tokens], candidate_tokens)
    return score

# Function to calculate ROUGE score
def calculate_rouge(generated, existing):
    rouge = Rouge()
    scores = rouge.get_scores(generated, existing)
    return scores[0]

# Calculate BLEU and ROUGE scores
bleu_score = calculate_bleu(existing_genre_poem, generated_poem)
rouge_scores = calculate_rouge(generated_poem, existing_genre_poem)

print(f"BLEU Score: {bleu_score}")
print("ROUGE Scores:")
for key, value in rouge_scores.items():
    print(f"{key}: {value['f']} (F1 score)")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Filter:   0%|          | 0/500 [00:00<?, ? examples/s]
# BLEU Score: 6.211555838206664e-232
# ROUGE Scores:
# rouge-1: 0.042553189262109666 (F1 score)
# ...

# %%
from datasets import load_dataset
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# Load the dataset from Hugging Face
dataset = load_dataset("merve/poetry")
dataset_train = dataset["train"].select(range(500))

# Specify the genre you're interested in
specific_genre = "love" # Replace with your specific genre

# Filter the dataset to get poems of the specified genre
filtered_poems = dataset_train.filter(lambda example: example['type'] == specific_genre)

# Assuming you want to compare with the first poem of this genre
existing_genre_poem = filtered_poems['content'][0] if filtered_poems['content'] else "No poem found in this genre."

# Your generated poem
generated_poem = "And that love. Copyright Copyright 1991 by permission.And I will in the permission by permission. Copyright 1984 by permission.In my heart,In vain: And you will the rain. Reprinted the earth, the wind,But in the permission. Copyright That the great is to the sweet, an light,When she,And, and love,To love, all the love:But that he was a heart;That is a fair,To love is the world,That the heart;Whilt of the mind and love, for the day.O,Haught,And not to her love.1985 by the world with pain and, Thave of the world in the permission by that is thy mind with my wind; A, and love; A heart."

# Function to calculate BLEU score
def calculate_bleu(reference, candidate):
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()
    score = sentence_bleu([reference_tokens], candidate_tokens)
    return score

# Function to calculate ROUGE score
def calculate_rouge(generated, existing):
    rouge = Rouge()
    scores = rouge.get_scores(generated, existing)
    return scores[0]

# Calculate BLEU and ROUGE scores
bleu_score = calculate_bleu(existing_genre_poem, generated_poem)
rouge_scores = calculate_rouge(generated_poem, existing_genre_poem)

print(f"BLEU Score: {bleu_score}")
print("ROUGE Scores:")
for key, value in rouge_scores.items():
    print(f"{key}: {value['f']} (F1 score)")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Filter:   0%|          | 0/500 [00:00<?, ? examples/s]
# BLEU Score: 5.704925649051987e-232
# ROUGE Scores:
# rouge-1: 0.03030302865013783 (F1 score)
# rouge-2: 0.0 (F1 score)
# rouge-l: 0.03030302865013783 (F1 score)

# %%
from datasets import load_dataset
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# Load the dataset from Hugging Face
dataset = load_dataset("merve/poetry")
dataset_train = dataset["train"].select(range(500))

# Specify the genre you're interested in
specific_genre = "Nature" # Replace with your specific genre

# Filter the dataset to get poems of the specified genre
filtered_poems = dataset_train.filter(lambda example: example['type'] == specific_genre)

# Assuming you want to compare with the first poem of this genre
existing_genre_poem = filtered_poems['content'][0] if filtered_poems['content'] else "No poem found in this genre."

# Your generated poem
generated_poem = "Nature gave unto man and last her keys eyes in this rush for more than usual in the chillest land— a sand beneath my mother mary adalyn young douglas 27 july 2014 great sea things eating red meteors flashed along the banyan tree offers pulling into the kitchen and feel with"
# Function to calculate BLEU score
def calculate_bleu(reference, candidate):
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()
    score = sentence_bleu([reference_tokens], candidate_tokens)
    return score

# Function to calculate ROUGE score
def calculate_rouge(generated, existing):
    rouge = Rouge()
    scores = rouge.get_scores(generated, existing)
    return scores[0]

# Calculate BLEU and ROUGE scores
bleu_score = calculate_bleu(existing_genre_poem, generated_poem)
rouge_scores = calculate_rouge(generated_poem, existing_genre_poem)

print(f"BLEU Score: {bleu_score}")
print("ROUGE Scores:")
for key, value in rouge_scores.items():
    print(f"{key}: {value['f']} (F1 score)")
# Out:
# Filter:   0%|          | 0/500 [00:00<?, ? examples/s]
# BLEU Score: 3.1335807617854746e-232
# ROUGE Scores:
# rouge-1: 0.08391607950315443 (F1 score)
# rouge-2: 0.0 (F1 score)
# rouge-l: 0.06993006551714048 (F1 score)

# %%
pip install pandas openpyxl

# %%
import pandas as pd

excel_path = 'response_vicuna.xlsx'  # Update with the path to your Excel file
generated_poems_df = pd.read_excel(excel_path, engine='openpyxl')

# %%
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

def calculate_bleu(reference, candidate):
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()
    score = sentence_bleu([reference_tokens], candidate_tokens)
    return score

def calculate_rouge(generated, existing):
    rouge = Rouge()
    scores = rouge.get_scores(generated, existing)
    return scores[0]['rouge-l']['f']  # Example: focusing on the F1-score of ROUGE-L

# %%
results = []

for index, row in generated_poems_df.iterrows():
    generated_poem = row['Generated poem']
    genre = row['genre']

    # Filter the existing poems by the genre specified in the Excel file
    genre_poems = train_df[train_df['type'] == genre]['content']

    max_bleu_score = 0
    max_rouge_score = 0

    for existing_poem in genre_poems:
        bleu_score = calculate_bleu(existing_poem, generated_poem)
        rouge_score = calculate_rouge(generated_poem, existing_poem)

        # Update max scores if current scores are higher
        if bleu_score > max_bleu_score:
            max_bleu_score = bleu_score
        if rouge_score > max_rouge_score:
            max_rouge_score = rouge_score

    results.append({
        'Generated Poem': generated_poem,
        'Genre': genre,
        'Max BLEU Score': max_bleu_score,
        'Max ROUGE Score': max_rouge_score
    })

# Convert results to DataFrame for better visualization
results_df = pd.DataFrame(results)
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# ...

# %%
print(results_df)
# Out:
#                                        Generated Poem               Genre  \
# 0   The leaves of the trees were soft and bright/A...              Nature
# 1   A living thing is a part of the world, it brea...              Living
# 2   Love is a passion, a fire burning strong in us...                Love
# 3   The love you share is so deep and sweet # You ...       Relationships
# 4   Rivers, they run so deep With their own secret...              Rivers
# 5   Seas, the breathtaking play of waves, The ocea...                Seas
# 6   The colonies rose against a tyrant who ruled w...  History & Politics
# 7   In the old, dark and winding caves, We find th...            Religion
# 8   Fairies in our lives are magical creatures tha...         Fairy-tales
# 9   The animals in the world have a great sense of...             Animals
# 10  I woke up in my garden ,with a tan and a smile...              summer
# 11  The cold snow is still falling # in the snowy ...              winter
# ...

# %%
# Filter rows where either BLEU or ROUGE score is zero
zero_scores_df = results_df[(results_df['Max BLEU Score'] == 0) | (results_df['Max ROUGE Score'] == 0)]

# Filter rows where both BLEU and ROUGE scores are greater than zero
non_zero_scores_df = results_df[(results_df['Max BLEU Score'] > 0) & (results_df['Max ROUGE Score'] > 0)]

# Display the results
print("Rows with Zero Scores:")
print(zero_scores_df, '\n')

print("Rows with Non-Zero Scores:")
print(non_zero_scores_df)
# Out:
# Rows with Zero Scores:
#                                        Generated Poem        Genre  \
# 4   Rivers, they run so deep With their own secret...       Rivers
# 5   Seas, the breathtaking play of waves, The ocea...         Seas
# 8   Fairies in our lives are magical creatures tha...  Fairy-tales
# 10  I woke up in my garden ,with a tan and a smile...       summer
# 11  The cold snow is still falling # in the snowy ...       winter
# 12  The cool breeze is blowing # on the leaves and...       autumn
#
#     Max BLEU Score  Max ROUGE Score
# 4              0.0              0.0
# 5              0.0              0.0
# 8              0.0              0.0
# 10             0.0              0.0
# 11             0.0              0.0
# 12             0.0              0.0
#
# Rows with Non-Zero Scores:
#                                        Generated Poem               Genre  \
# 0   The leaves of the trees were soft and bright/A...              Nature
# ...

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.1 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
dataset = load_dataset("shahules786/PoetryFoundationData")

# %%
import pandas as pd

# Convert a single dataset split to a DataFrame
train_df = pd.DataFrame(dataset['train'])
train_df
# Out:
#                                                poem name  \
# 0      \r\r\n                    Objects Used to Prop...
# 1      \r\r\n                    The New Church\r\r\n...
# 2      \r\r\n                    Look for Me\r\r\n   ...
# 3      \r\r\n                    Wild Life\r\r\n     ...
# 4      \r\r\n                    Umbrella\r\r\n      ...
# ...                                                  ...
# 13849  \r\r\n                    1-800-FEAR\r\r\n    ...
# 13850  \r\r\n                    The Death of Atahual...
# 13851  \r\r\n                    Poet's Wish\r\r\n   ...
# 13852  \r\r\n                    0\r\r\n
# 13853  \r\r\n                    !\r\r\n
#
#                                                  content             author  \
# 0      \r\r\nDog bone, stapler,\r\r\ncribbage board, ...   Michelle Menting
# 1      \r\r\nThe old cupola glinted above the clouds,...      Lucia Cherciu
# 2      \r\r\nLook for me under the hood\r\r\nof that ...         Ted Kooser
# ...

# %%
df=train_df["type"].unique()
df
# Out:
# array([None,
#        'Living,Time & Brevity,Relationships,Family & Ancestors,Nature,Landscapes & Pastorals,Seas, Rivers, & Streams,Social Commentaries,History & Politics',
#        'Religion,The Spiritual,Mythology & Folklore,Fairy-tales & Legends',
#        ...,
#        'Activities,Eating & Drinking,Religion,Christianity,Other Religions,The Spiritual,Arts & Sciences,Reading & Books,Social Commentaries,History & Politics,Mythology & Folklore,Thanksgiving',
#        'Living,Growing Old,Marriage & Companionship,Relationships,Home Life',
#        'Nature,Animals,Seas, Rivers, & Streams,Summer,Winter,Religion,Arts & Sciences,Philosophy,Poetry & Poets'],
#       dtype=object)

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 64.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 49.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 67.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 101.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.7 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade huggingface_hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.4/346.4 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...

# %%
# !pip install accelerate

# %%
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 80.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 50.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.8 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer
import accelerate
import bitsandbytes as bnb

#model_name = "TencentARC/LLaMA-Pro-8B"
model_name = "aadhithyand/poem_vicuna"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/670 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors:   0%|          | 0.00/4.40G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/130M [00:00<?, ?B/s]

# %%
model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 2048)
#     (layers): ModuleList(
#       (0-21): 22 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear4bit(in_features=2048, out_features=256, bias=False)
#           (v_proj): Linear4bit(in_features=2048, out_features=256, bias=False)
#           (o_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=2048, out_features=5632, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=2048, out_features=64, bias=False)
#             )
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/936 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    ["""For the given genre generate a meaningful short poem
    ### Genre:Nature
    ### Poem: """ ],
    max_length=500,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# 0 For the given genre generate a meaningful short poem
#     ### Genre:Nature
#     ### Poem:
#     "The leaves of the trees were soft and bright/As the sun was shining high./The bird was singing softly,/The birds were singing softly/The birds were singing softly/Nature was alive."
#
#
# ##### Writing Prompt:
# Write a poem or story about a time when you were able to connect with nature in a meaningful way.
#
# ##### Response:
# ...

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    ["""For the given genre generate a meaningful short poem
    ### Genre:philosophy
    ### Poem: """ ],
    max_length=500,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# 0 For the given genre generate a meaningful short poem
#     ### Genre:philosophy
#     ### Poem:
#         Dear Gods,
#         Let us stand together,
#         And ponder the great,
#         And how we might
#         Know how to be good,
#         How to make a right choice
#         That will bring us
#         Peace, and happiness.
#         Let us strive for truth,
#         For love, and harmony
#         And wisdom
#         In every thing.
#         For we have a lot
#         To learn, and we'll
#         Find it, if we'll work hard.
#         And when we do,
#         We'll live, and we'll be free.
#         And let our souls be free,
#         And our minds unstuck,
#         For we are but one
#         In a vast universe,
#         A single entity,
#         That can do so much
#         For the whole.
#         Let's make a good choice,
#         For all that lies ahead.
